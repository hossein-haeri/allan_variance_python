# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
import avar
# %matplotlib inline

path = os.getcwd() + "\\apple_watch_data"
csv_files = glob.glob(os.path.join(path, "*.dat"))
data = pd.read_csv(csv_files[16], names=['time','x','y','z'], delim_whitespace=True)
# data = pd.read_csv('apple_watch_data/1444079161.m_watch_acc.dat', names=['time','x','y','z'], delim_whitespace=True)
print(data)
# Out:
#         time     x     y       z
# 0       44.0   8.0 -48.0 -1024.0
# 1       84.0   8.0 -32.0 -1016.0
# 2      124.0   8.0 -32.0 -1048.0
# 3      164.0  16.0 -32.0 -1040.0
# 4      204.0  16.0 -32.0 -1048.0
# ..       ...   ...   ...     ...
# 495  19706.0  16.0 -40.0 -1024.0
# 496  19746.0  16.0 -40.0 -1040.0
# 497  19786.0   8.0 -32.0 -1024.0
# 498  19826.0  16.0 -16.0 -1040.0
# 499  19866.0   8.0 -32.0 -1032.0
#
# [500 rows x 4 columns]

# %% [markdown]
# # Allan Variance Analysis

# %%
fig = plt.figure()
fig.set_size_inches(6, 4)
ax = fig.add_subplot(2, 1, 1)

ax.plot(data['x'])
ax.plot(data['y'])
plt.plot(data['z'])
ax.set_xlabel('Timestep [25 Hz]')
ax.set_ylabel('acceleration [mG]')
ax.legend(['x','y','z'])


ct = avar.CharacteristicScale()

ax = fig.add_subplot(2, 1, 2)
ax.plot(ct.allanvar(data['x']))
ax.plot(ct.allanvar(data['y']))
plt.plot(ct.allanvar(data['z']))
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Timescale [# of samples]')
ax.set_ylabel('$\sigma_A^2$')
ax.legend(['x','y'])
fig.tight_layout()

# %% [markdown]
# # Dynamic Allan Variance Analysis

# %%
from scipy.ndimage import gaussian_filter1d

fig, axs = plt.subplots(2)
# horizons = [100, 200, 500]
horizons = [100]
for h in horizons:
    char = avar.CharacteristicScale(horizon=h)
    
    M_c = []
    for day, v in enumerate(data['x']):
        char.memory.append(v)
        if day > 200:
            davar = char.dynallanvar()
#             davar = gaussian_filter1d(davar, 1)
            m_c = char.find_charecteristic_scale(davar)
            M_c.append(m_c)
        else:
            M_c.append(1)
    print(char.taus, char.horizon)
    axs[1].plot(M_c, label='horizon = '+str(h))
    axs[1].set_xlabel('Time [day]')
    axs[1].set_ylabel('Characteristic Timescale [day]')
    axs[1].set_yscale("log")
    axs[1].legend()
axs[0].plot(data['x'])
axs[0].set_xlabel('Time [day]')
axs[0].set_ylabel('ETH Daily Volume')
plt.show()
# Out:
# range(1, 50)
